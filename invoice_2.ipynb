# %%
# Data Manipulation
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
data_invoice = pd.ExcelFile('C:\\Users\\Jyotishman Parasar\\DataanalysisChallenge\\data\\invoice_ext.xlsx')

# %%
df = data_invoice.parse('Sheet1')

# %%
df.head()
# Out:
#    Unnamed: 0  V1  INVOICING_ID    INV_CREATED_DATE    INVOICE_STATUS  \
# 0           3   3        161397 2019-02-18 17:59:53           AP_PAID
# 1          17  17        875084 2020-05-21 10:14:24           AP_PAID
# 2          20  20        478599 2019-11-18 09:11:02           AP_PAID
# 3          50  50        322744 2019-08-06 14:56:30  VENDOR_CANCELLED
# 4          57  57        214540 2019-05-09 00:32:57           AP_PAID
#
#      GR_DATE    IR_DATE BID_UNIT    BID_UNIT_SHORT_DESCRIPTION  UNIT  ...  \
# 0 2019-02-20 2019-02-28  E-400.1  Permits in Hand - LLD Aerial  foot  ...
# 1 2020-06-15 2020-06-15  E-300.2         Cable Placed - New UG  foot  ...
# 2 2019-11-25 2019-11-25  E-200.1          Permits in Hand - PM  foot  ...
# 3        NaT        NaT  E-200.2    Construction Complete - PM  foot  ...
# 4 2018-11-06 2018-11-09  E-400.2         Cable Placed - Aerial  foot  ...
#
#    CONSTRUCTION_TYPE_GRP  INVOICE_TYPE  INVOICE_DATE          SEG_STATUS  \
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      V1  INVOICING_ID    INV_CREATED_DATE INVOICE_STATUS  \
# 58299      811645  811645        119895 2018-09-05 13:14:25        AP_PAID
# 58300      811659  811659        952579 2020-06-12 13:03:04   VENDOR_SAVED
# 58301      811668  811668        492454 2019-11-25 19:27:33        AP_PAID
# 58302      811672  811672        488173 2019-11-22 17:21:55        AP_PAID
# 58303      811674  811674        764738 2020-04-09 16:55:04        AP_PAID
#
#          GR_DATE    IR_DATE  BID_UNIT  \
# 58299 2018-10-02 2018-10-08     C-510
# 58300        NaT        NaT  C-100.1B
# 58301 2018-09-10 2018-09-11   C-100.1
# 58302 2018-05-03 2018-05-08   E-300.1
# 58303 2020-04-14 2020-04-14   E-300.1
#
#                               BID_UNIT_SHORT_DESCRIPTION   UNIT  ...  \
# 58299                    Cable Prep/Splice/Test (Ribbon)  fiber  ...
# 58300  Cable Placed - New UG (B/T/P) (Inv'd w/Conduit...   foot  ...
# 58301                      Cable Placed - New UG (B/T/P)   foot  ...
# ...

# %%
df.shape
# Out:
# (58304, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58304 entries, 0 to 58303
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  58304 non-null  int64
#  1   V1                          58304 non-null  int64
#  2   INVOICING_ID                58304 non-null  int64
#  3   INV_CREATED_DATE            58304 non-null  datetime64[ns]
#  4   INVOICE_STATUS              58304 non-null  object
#  5   GR_DATE                     50754 non-null  datetime64[ns]
#  6   IR_DATE                     49477 non-null  datetime64[ns]
#  7   BID_UNIT                    58304 non-null  object
#  8   BID_UNIT_SHORT_DESCRIPTION  58304 non-null  object
#  9   UNIT                        58304 non-null  object
#  10  QUANTITY                    58304 non-null  float64
#  11  UNIT_RATE                   58304 non-null  float64
# ...

# %%
# Checking missing values
df.isna().sum()
df['LABOR_AMOUNT'] = df['LABOR_AMOUNT'].fillna(0)

# %%
# Generating descriptive statistics summary
df.describe().round()
# Out:
#        Unnamed: 0        V1  INVOICING_ID   QUANTITY  UNIT_RATE  \
# count     58304.0   58304.0       58304.0    58304.0    58304.0
# mean     406968.0  406968.0      591517.0     2755.0       54.0
# std      234566.0  234566.0      381700.0    52360.0     1881.0
# min           3.0       3.0      100015.0   -38702.0        0.0
# 25%      203724.0  203724.0      214539.0      133.0        0.0
# 50%      408560.0  408560.0      488118.0      502.0        2.0
# 75%      611709.0  611709.0      844777.0     1359.0       12.0
# max      811674.0  811674.0     1380679.0  6342838.0   200000.0
#
#        MILESTONE_PERCENTAGE  MILESTONE_RATE  LABOR_AMOUNT  MATERIALS_AMOUNT  \
# count               58301.0         58245.0       58304.0           58304.0
# mean                   54.0            50.0        3029.0               4.0
# std                    27.0          1881.0       16795.0             693.0
# min                     0.0             0.0     -128706.0               0.0
# ...

# %%
# Getting month year from INVOICE_DATE
df['month_year'] = df['INVOICE_DATE'].apply(lambda x: x.strftime('%Y-%m'))

# %%
# grouping month_year by LABOR_AMOUNt
df_temp = df.groupby('month_year').sum()['LABOR_AMOUNT'].reset_index()

# %%
# Setting the figure size
plt.figure(figsize=(16, 5))
plt.plot(df_temp['month_year'], df_temp['LABOR_AMOUNT'], color='#b80045')
plt.xticks(rotation='vertical', size=8)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# D:\Anaconda\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# D:\Anaconda\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
## This is the calculation of total labour amount w.r.t the market id
labor_amt = pd.DataFrame(df.groupby('MARKET_ID').sum()['LABOR_AMOUNT'])


labor_amt.sort_values(by=['LABOR_AMOUNT'], inplace=True, ascending=False)

labor_amt
# Out:
#            LABOR_AMOUNT
# MARKET_ID
# 69         1.338258e+08
# 68         2.839728e+07
# 67         1.440133e+07

# %%
## This is the total labour amount w.r.t the market id

plt.figure(figsize=(10,6))
plt.bar('MARKET_ID','LABOR_AMOUNT',data=df,color='y')
plt.show()

# %%
df = df.sort_values('INVOICE_DATE')

# %%
df = df.groupby('INVOICE_DATE')['LABOR_AMOUNT'].sum().reset_index()

# %%
df = df.set_index('INVOICE_DATE')
df.index
# Out:
# DatetimeIndex(['2016-11-30', '2017-07-03', '2017-08-01', '2017-08-09',
#                '2017-08-10', '2017-08-29', '2017-09-11', '2017-09-28',
#                '2017-10-18', '2017-10-26',
#                ...
#                '2020-09-15', '2020-09-16', '2020-09-17', '2020-09-18',
#                '2020-09-19', '2020-09-20', '2020-09-21', '2020-09-22',
#                '2020-09-23', '2020-09-24'],
#               dtype='datetime64[ns]', name='INVOICE_DATE', length=519, freq=None)

# %%
y = df['LABOR_AMOUNT'].resample('MS').mean()

# %%
## Total Labour amount in the year 2020

y['2020':]
# Out:
# INVOICE_DATE
# 2020-01-01    326729.591053
# 2020-02-01    220293.253333
# 2020-03-01    275857.649091
# 2020-04-01    337849.614762
# 2020-05-01    221285.350909
# 2020-06-01    430472.809130
# 2020-07-01    335387.892273
# 2020-08-01    295630.126957
# 2020-09-01    250868.632105
# Freq: MS, Name: LABOR_AMOUNT, dtype: float64

# %%
y['2020':].sum()
# Out:
# 2694374.9196128165

# %%
## Total Labour amount in the year 2020

y['2019':]
# Out:
# INVOICE_DATE
# 2019-01-01     27948.714667
# 2019-02-01    158453.045000
# 2019-03-01    176574.217000
# 2019-04-01    101960.164118
# 2019-05-01     79979.564737
# 2019-06-01     91977.432632
# 2019-07-01    528972.906190
# 2019-08-01    164909.826471
# 2019-09-01    421261.088421
# 2019-10-01    644219.392609
# 2019-11-01    448681.838421
# 2019-12-01    593519.635556
# 2020-01-01    326729.591053
# 2020-02-01    220293.253333
# 2020-03-01    275857.649091
# 2020-04-01    337849.614762
# 2020-05-01    221285.350909
# 2020-06-01    430472.809130
# 2020-07-01    335387.892273
# 2020-08-01    295630.126957
# 2020-09-01    250868.632105
# Freq: MS, Name: LABOR_AMOUNT, dtype: float64

# %%
y['2019':].sum()
# Out:
# 6132832.745432972

# %%
y['2018':]
# Out:
# INVOICE_DATE
# 2018-01-01    0.000000e+00
# 2018-02-01    2.059852e+05
# 2018-03-01    5.830084e+05
# 2018-04-01    6.495986e+05
# 2018-05-01    1.611957e+04
# 2018-06-01    7.233541e+04
# 2018-07-01    1.011960e+03
# 2018-08-01    2.145904e+05
# 2018-09-01    7.933856e+04
# 2018-10-01    1.333601e+06
# 2018-11-01    1.572831e+05
# 2018-12-01    5.274264e+05
# 2019-01-01    2.794871e+04
# 2019-02-01    1.584530e+05
# 2019-03-01    1.765742e+05
# 2019-04-01    1.019602e+05
# 2019-05-01    7.997956e+04
# 2019-06-01    9.197743e+04
# 2019-07-01    5.289729e+05
# 2019-08-01    1.649098e+05
# 2019-09-01    4.212611e+05
# 2019-10-01    6.442194e+05
# 2019-11-01    4.486818e+05
# 2019-12-01    5.935196e+05
# 2020-01-01    3.267296e+05
# 2020-02-01    2.202933e+05
# 2020-03-01    2.758576e+05
# 2020-04-01    3.378496e+05
# 2020-05-01    2.212854e+05
# 2020-06-01    4.304728e+05
# 2020-07-01    3.353879e+05
# 2020-08-01    2.956301e+05
# 2020-09-01    2.508686e+05
# ...

# %%
y['2017':]
# Out:
# INVOICE_DATE
# 2017-01-01             NaN
# 2017-02-01             NaN
# 2017-03-01             NaN
# 2017-04-01             NaN
# 2017-05-01             NaN
# 2017-06-01             NaN
# 2017-07-01    0.000000e+00
# 2017-08-01    1.149915e+06
# 2017-09-01    3.797430e+04
# 2017-10-01    1.622410e+05
# 2017-11-01    1.022042e+05
# 2017-12-01    6.390899e+05
# 2018-01-01    0.000000e+00
# 2018-02-01    2.059852e+05
# 2018-03-01    5.830084e+05
# 2018-04-01    6.495986e+05
# 2018-05-01    1.611957e+04
# 2018-06-01    7.233541e+04
# 2018-07-01    1.011960e+03
# 2018-08-01    2.145904e+05
# 2018-09-01    7.933856e+04
# 2018-10-01    1.333601e+06
# 2018-11-01    1.572831e+05
# 2018-12-01    5.274264e+05
# 2019-01-01    2.794871e+04
# 2019-02-01    1.584530e+05
# 2019-03-01    1.765742e+05
# 2019-04-01    1.019602e+05
# 2019-05-01    7.997956e+04
# 2019-06-01    9.197743e+04
# 2019-07-01    5.289729e+05
# 2019-08-01    1.649098e+05
# 2019-09-01    4.212611e+05
# ...

# %%
y['2016':]
# Out:
# INVOICE_DATE
# 2016-11-01    1.113511e+06
# 2016-12-01             NaN
# 2017-01-01             NaN
# 2017-02-01             NaN
# 2017-03-01             NaN
# 2017-04-01             NaN
# 2017-05-01             NaN
# 2017-06-01             NaN
# 2017-07-01    0.000000e+00
# 2017-08-01    1.149915e+06
# 2017-09-01    3.797430e+04
# 2017-10-01    1.622410e+05
# 2017-11-01    1.022042e+05
# 2017-12-01    6.390899e+05
# 2018-01-01    0.000000e+00
# 2018-02-01    2.059852e+05
# 2018-03-01    5.830084e+05
# 2018-04-01    6.495986e+05
# 2018-05-01    1.611957e+04
# 2018-06-01    7.233541e+04
# 2018-07-01    1.011960e+03
# 2018-08-01    2.145904e+05
# 2018-09-01    7.933856e+04
# 2018-10-01    1.333601e+06
# 2018-11-01    1.572831e+05
# 2018-12-01    5.274264e+05
# 2019-01-01    2.794871e+04
# 2019-02-01    1.584530e+05
# 2019-03-01    1.765742e+05
# 2019-04-01    1.019602e+05
# 2019-05-01    7.997956e+04
# 2019-06-01    9.197743e+04
# 2019-07-01    5.289729e+05
# ...
